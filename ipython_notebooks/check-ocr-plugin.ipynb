# %%
import tesserocr
available_languages = tesserocr.get_languages("/opt/dataiku/code-env/resources/document_extraction_models/tessdata")
print(f"Available languages: {available_languages}")
available_languages = tesserocr.get_languages("/usr/share/tesseract/tessdata")
print(f"Available languages: {available_languages}")

# %%
import subprocess
print(subprocess.check_output(["tesseract", "--list-langs"]).decode("utf-8"))
